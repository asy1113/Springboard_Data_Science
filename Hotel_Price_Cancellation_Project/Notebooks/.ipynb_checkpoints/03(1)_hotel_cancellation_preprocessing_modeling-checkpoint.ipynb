# %% [markdown]
# # Preprocessing and Training Data

# %%
# import necessary packages and load dataset

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV, RandomizedSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn import tree
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix, classification_report
from tabulate import tabulate

import shap

# %%
df = pd.read_csv('../data/hotel_data_cleaned.csv')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year  \
# 0  Resort Hotel            0          7               2015
# 1  Resort Hotel            0         13               2015
# 2  Resort Hotel            0         14               2015
# 3  Resort Hotel            0         14               2015
# 4  Resort Hotel            0          0               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day  \
# 0                   7                        27                 1
# 1                   7                        27                 1
# 2                   7                        27                 1
# 3                   7                        27                 1
# 4                   7                        27                 1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     1       1  ...      Transient
# 1                        0                     1       1  ...      Transient
# 2                        0                     2       2  ...      Transient
# 3                        0                     2       2  ...      Transient
# 4                        0                     2       2  ...      Transient
#
#      adr required_car_parking_spaces total_of_special_requests  \
# 0   75.0                           0                         0
# 1   75.0                           0                         0
# 2   98.0                           0                         1
# 3   98.0                           0                         1
# 4  107.0                           0                         0
#
#   reservation_status reservation_status_date_year  \
# 0          Check-Out                         2015
# 1          Check-Out                         2015
# 2          Check-Out                         2015
# 3          Check-Out                         2015
# 4          Check-Out                         2015
#
#    reservation_status_date_month  reservation_status_date_day  \
# 0                              7                            2
# 1                              7                            2
# 2                              7                            3
# 3                              7                            3
# 4                              7                            3
#
#    reservation_status_day_of_week arrival_date_day_of_week
# 0                        Thursday                Wednesday
# 1                        Thursday                Wednesday
# 2                          Friday                Wednesday
# 3                          Friday                Wednesday
# 4                          Friday                Wednesday
#
# [5 rows x 35 columns]

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                  int64
# arrival_date_week_number            int64
# arrival_date_day                    int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# deposit_type                       object
# agent                             float64
# days_in_waiting_list                int64
# customer_type                      object
# adr                               float64
# required_car_parking_spaces         int64
# total_of_special_requests           int64
# reservation_status                 object
# reservation_status_date_year        int64
# reservation_status_date_month       int64
# reservation_status_date_day         int64
# reservation_status_day_of_week     object
# arrival_date_day_of_week           object
# dtype: object

# %%
# dropping target leakage variable

df=df.drop(columns='reservation_status')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0          7               2015
# 1       Resort Hotel            0         13               2015
# 2       Resort Hotel            0         14               2015
# 3       Resort Hotel            0         14               2015
# 4       Resort Hotel            0          0               2015
# ...              ...          ...        ...                ...
# 116946    City Hotel            0         23               2017
# 116947    City Hotel            0        102               2017
# 116948    City Hotel            0         34               2017
# 116949    City Hotel            0        109               2017
# 116950    City Hotel            0        205               2017
#
#         arrival_date_month  arrival_date_week_number  arrival_date_day  \
# 0                        7                        27                 1
# 1                        7                        27                 1
# 2                        7                        27                 1
# 3                        7                        27                 1
# 4                        7                        27                 1
# ...                    ...                       ...               ...
# 116946                   8                        35                30
# 116947                   8                        35                31
# 116948                   8                        35                31
# 116949                   8                        35                31
# 116950                   8                        35                29
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                             0                     1       1  ...
# 1                             0                     1       1  ...
# 2                             0                     2       2  ...
# 3                             0                     2       2  ...
# 4                             0                     2       2  ...
# ...                         ...                   ...     ...  ...
# 116946                        2                     5       2  ...
# 116947                        2                     5       3  ...
# 116948                        2                     5       2  ...
# 116949                        2                     5       2  ...
# 116950                        2                     7       2  ...
#
#         days_in_waiting_list  customer_type     adr  \
# 0                          0      Transient   75.00
# 1                          0      Transient   75.00
# 2                          0      Transient   98.00
# 3                          0      Transient   98.00
# 4                          0      Transient  107.00
# ...                      ...            ...     ...
# 116946                     0      Transient   96.14
# 116947                     0      Transient  225.43
# 116948                     0      Transient  157.71
# 116949                     0      Transient  104.40
# 116950                     0      Transient  151.20
#
#        required_car_parking_spaces total_of_special_requests  \
# 0                                0                         0
# 1                                0                         0
# 2                                0                         1
# 3                                0                         1
# 4                                0                         0
# ...                            ...                       ...
# 116946                           0                         0
# 116947                           0                         2
# 116948                           0                         4
# 116949                           0                         0
# 116950                           0                         2
#
#        reservation_status_date_year  reservation_status_date_month  \
# 0                              2015                              7
# 1                              2015                              7
# 2                              2015                              7
# 3                              2015                              7
# 4                              2015                              7
# ...                             ...                            ...
# 116946                         2017                              9
# 116947                         2017                              9
# 116948                         2017                              9
# 116949                         2017                              9
# 116950                         2017                              9
#
#         reservation_status_date_day  reservation_status_day_of_week  \
# 0                                 2                        Thursday
# 1                                 2                        Thursday
# 2                                 3                          Friday
# 3                                 3                          Friday
# 4                                 3                          Friday
# ...                             ...                             ...
# 116946                            6                       Wednesday
# 116947                            7                        Thursday
# 116948                            7                        Thursday
# 116949                            7                        Thursday
# 116950                            7                        Thursday
#
#        arrival_date_day_of_week
# 0                     Wednesday
# 1                     Wednesday
# 2                     Wednesday
# 3                     Wednesday
# 4                     Wednesday
# ...                         ...
# 116946                Wednesday
# 116947                 Thursday
# 116948                 Thursday
# 116949                 Thursday
# 116950                  Tuesday
#
# [116951 rows x 34 columns]

# %% [markdown]
# ## Transform categorical, text data

# %%
df1= pd.get_dummies(df, columns=['hotel','arrival_date_day_of_week','meal', 'country', 
                                 'market_segment', 'distribution_channel', 'reserved_room_type', 
                                 'assigned_room_type', 'deposit_type', 'customer_type',
                                 'reservation_status_day_of_week'], drop_first=False)
df1.shape
# Out:
# (116951, 260)

# %%
df.agent.value_counts()
# Out:
# 9.0      31813
# 0.0      15231
# 240.0    13763
# 1.0       7050
# 14.0      3614
#          ...
# 352.0        1
# 480.0        1
# 451.0        1
# 165.0        1
# 472.0        1
# Name: agent, Length: 332, dtype: int64

# %% [markdown]
# ## Train/Test Split (Churn)

# %%
len(df1) * .7, len(df1) * .3
# Out:
# (81865.7, 35085.299999999996)

# %%
X_train, X_test, y_train, y_test = train_test_split(df1.drop(columns='is_canceled'), 
                                                    df1.is_canceled, test_size=0.3, 
                                                    random_state=100)

# %%
X_train.shape, X_test.shape
# Out:
# ((81865, 259), (35086, 259))

# %%
y_train.shape, y_test.shape
# Out:
# ((81865,), (35086,))

# %% [markdown]
# # Classification Models
#
# 1. Logistic Regression
# 2. KNN
# 3. SVM
# 4. Decision Tree
# 5. Random Forest
# 6. Gradient Boosting

# %% [markdown]
# ### Logistic Regression

# %%
logreg= LogisticRegression()

logreg.fit(X_train, y_train)
# Out:
# /Users/soyoungan/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
prediction_log = logreg.predict(X_test)

# %%
print (confusion_matrix(y_test, prediction_log))
print (classification_report(y_test, prediction_log))
# Out:
# [[19966  1919]
#  [ 8205  4996]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80     21885
#            1       0.72      0.38      0.50     13201
#
#     accuracy                           0.71     35086
#    macro avg       0.72      0.65      0.65     35086
# weighted avg       0.71      0.71      0.68     35086

# %% [markdown]
# Note for Logistic Regression
#
# 0 Precision represents the percent of your no-cancelled classifier
# 1 Precision represents  cancelled prediction

# %% [markdown]
# ### KNN

# %%
# neighbors = np.arange(3, 5)
# train_accuracy = np.empty(len(neighbors))
# test_accuracy = np.empty(len(neighbors))

# for i, k in enumerate (neighbors):
#     print (k)
#     knn = KNeighborsClassifier(n_neighbors=k)
#     knn.fit(X_train, y_train)
#     train_accuracy[i]=knn.score(X_train, y_train)
#     test_accuracy[i]=knn.score(X_test, y_test)

# plt.title('KNN: Varying Number of Neighbors')
# plt.plot(neighbors, test_accuracy, label='Testing Accuracy')
# plt.plot(neighbors, train_accuracy, label='Training Accuracy')
# plt.legend()
# plt.xlabel('Number of Neighbors')
# plt.ylabel('Accuracy')
# plt.show()

# %%
clf_knn = KNeighborsClassifier(n_neighbors=5)

clf_knn.fit(X_train, y_train)
y_pred_knn = clf_knn.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_knn))
print (classification_report(y_test, y_pred_knn))
# Out:
# [[20633  1252]
#  [ 3414  9787]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90     21885
#            1       0.89      0.74      0.81     13201
#
#     accuracy                           0.87     35086
#    macro avg       0.87      0.84      0.85     35086
# weighted avg       0.87      0.87      0.86     35086

# %% [markdown]
# ### Linear SVM

# %%
clf_lsvm = LinearSVC()

clf_lsvm.fit(X_train, y_train)
y_pred_svm = clf_lsvm.predict(X_test)
# Out:
# /Users/soyoungan/opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
print (confusion_matrix(y_test, y_pred_svm))
print (classification_report(y_test, y_pred_svm))
# Out:
# [[ 6645 15240]
#  [  305 12896]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.30      0.46     21885
#            1       0.46      0.98      0.62     13201
#
#     accuracy                           0.56     35086
#    macro avg       0.71      0.64      0.54     35086
# weighted avg       0.77      0.56      0.52     35086

# %% [markdown]
# ### Decision Tree

# %%
# default params: gini, max_depth = None, min_samples_split = 2, min_samples_leaf = 1

clf_dt = tree.DecisionTreeClassifier(random_state = 47)

clf_dt.fit(X_train, y_train)
y_pred_dt = clf_dt.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_dt))
print (classification_report(y_test, y_pred_dt))
# Out:
# [[21089   796]
#  [  893 12308]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     21885
#            1       0.94      0.93      0.94     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.95      0.95      0.95     35086
# weighted avg       0.95      0.95      0.95     35086

# %% [markdown]
# #### Feature Importance - Decision Tree

# %%
headers = ["name", "score"]
values_dt = sorted(zip(X_train.columns, clf_dt.feature_importances_), key=lambda x: x[1] * -1)
print('Feature Importance - Decision Tree')
print(tabulate(values_dt, headers, tablefmt="plain"))
# Out:
# Feature Importance - Decision Tree
# name                                            score
# deposit_type_Non Refund                   0.231992
# reservation_status_date_month             0.081724
# arrival_date_week_number                  0.0791298
# market_segment_Online TA                  0.0623794
# lead_time                                 0.0537492
# total_of_special_requests                 0.0481218
# reservation_status_date_day               0.047269
# country_PRT                               0.0410268
# arrival_date_month                        0.0355712
# agent                                     0.0332353
# reservation_status_date_year              0.0289941
# arrival_date_day                          0.0283431
# arrival_date_year                         0.0229983
# required_car_parking_spaces               0.022191
# reservation_status_day_of_week_Sunday     0.0205965
# stays_in_week_nights                      0.0169461
# adr                                       0.0156025
# previous_cancellations                    0.013413
# stays_in_weekend_nights                   0.0120195
# reservation_status_day_of_week_Monday     0.00699491
# reservation_status_day_of_week_Saturday   0.00677815
# booking_changes                           0.00663362
# customer_type_Transient                   0.00533786
# reservation_status_day_of_week_Tuesday    0.00511667
# reservation_status_day_of_week_Thursday   0.00403415
# reservation_status_day_of_week_Wednesday  0.00352067
# arrival_date_day_of_week_Monday           0.00329785
# previous_bookings_not_canceled            0.00323033
# arrival_date_day_of_week_Saturday         0.00319445
# adults                                    0.00303958
# arrival_date_day_of_week_Friday           0.00284337
# market_segment_Direct                     0.00261169
# reservation_status_day_of_week_Friday     0.00247159
# arrival_date_day_of_week_Sunday           0.00233615
# country_DEU                               0.00223498
# market_segment_Corporate                  0.00213406
# hotel_City Hotel                          0.00195556
# customer_type_Transient-Party             0.0018194
# assigned_room_type_A                      0.00153554
# children                                  0.00130517
# arrival_date_day_of_week_Tuesday          0.00121899
# country_AGO                               0.00119775
# arrival_date_day_of_week_Wednesday        0.00118143
# arrival_date_day_of_week_Thursday         0.0011524
# country_ITA                               0.00101538
# meal_Undefined                            0.000939656
# country_BRA                               0.000928749
# reserved_room_type_A                      0.000876645
# reserved_room_type_D                      0.000875131
# meal_SC                                   0.000863773
# assigned_room_type_D                      0.000819691
# customer_type_Contract                    0.000810115
# days_in_waiting_list                      0.000778579
# country_USA                               0.000761749
# market_segment_Groups                     0.000731894
# country_CHN                               0.000719059
# country_GBR                               0.0006525
# meal_BB                                   0.000647684
# meal_FB                                   0.000632422
# distribution_channel_TA/TO                0.00060168
# market_segment_Offline TA/TO              0.000592238
# country_FRA                               0.000542047
# hotel_Resort Hotel                        0.000523974
# reserved_room_type_E                      0.000473081
# meal_HB                                   0.000453731
# assigned_room_type_B                      0.000422215
# assigned_room_type_E                      0.000386322
# distribution_channel_Direct               0.000380704
# is_repeated_guest                         0.000330689
# reserved_room_type_B                      0.000330008
# country_CHE                               0.00032342
# country_CN                                0.000318401
# country_TUR                               0.000309975
# assigned_room_type_C                      0.000307381
# country_MAR                               0.000302855
# market_segment_Aviation                   0.000293136
# reserved_room_type_F                      0.000292261
# country_ESP                               0.000285075
# country_BEL                               0.000256681
# country_SWE                               0.00024922
# babies                                    0.000248768
# country_PHL                               0.000245739
# assigned_room_type_F                      0.00024555
# assigned_room_type_G                      0.000243482
# country_NGA                               0.000234125
# country_RUS                               0.000230154
# country_AUT                               0.000195484
# reserved_room_type_G                      0.000191975
# distribution_channel_Corporate            0.000188145
# country_THA                               0.00018723
# reserved_room_type_C                      0.00018496
# country_VEN                               0.000179038
# country_IRL                               0.000177671
# assigned_room_type_K                      0.000158954
# country_ZAF                               0.000158525
# deposit_type_No Deposit                   0.000149377
# country_IRN                               0.000146611
# country_SAU                               0.00014317
# country_AUS                               0.000140488
# distribution_channel_GDS                  0.00013649
# country_POL                               0.000130703
# country_not available                     0.00011678
# country_HUN                               0.000111514
# assigned_room_type_H                      0.000110447
# country_NOR                               0.000109565
# country_ISR                               0.000106863
# reserved_room_type_H                      0.000106691
# country_TUN                               9.92871e-05
# country_ARE                               9.82159e-05
# country_IND                               9.63206e-05
# deposit_type_Refundable                   9.62878e-05
# country_PER                               9.60349e-05
# country_NLD                               9.57171e-05
# country_OMN                               9.56621e-05
# country_ECU                               9.48192e-05
# market_segment_Complementary              9.45927e-05
# country_GRC                               9.45764e-05
# country_TZA                               9.22357e-05
# country_KOR                               9.14366e-05
# country_DZA                               9.12986e-05
# country_CPV                               9.05685e-05
# country_LUX                               9.00824e-05
# country_HKG                               8.90138e-05
# country_CHL                               7.7443e-05
# country_ROU                               7.65925e-05
# country_COL                               6.46608e-05
# country_GNB                               5.19781e-05
# country_QAT                               5.12224e-05
# country_JPN                               5.11358e-05
# country_JEY                               4.97939e-05
# country_TWN                               4.95945e-05
# country_EGY                               4.92949e-05
# assigned_room_type_I                      4.81466e-05
# country_ZMB                               4.72096e-05
# country_ZWE                               4.71144e-05
# country_SGP                               4.69473e-05
# country_CZE                               4.62464e-05
# country_PAK                               4.61492e-05
# country_UMI                               4.61299e-05
# country_SVK                               4.57648e-05
# country_MKD                               4.5755e-05
# country_MEX                               4.55759e-05
# country_IDN                               4.5325e-05
# country_MDV                               4.50258e-05
# country_GGY                               4.49006e-05
# country_GIB                               4.44609e-05
# country_DNK                               4.26131e-05
# country_KAZ                               4.25891e-05
# country_MAC                               4.04849e-05
# country_HRV                               2.51973e-05
# country_BGR                               2.41933e-05
# country_FIN                               2.41161e-05
# reserved_room_type_L                      2.23376e-05
# country_ARG                               1.14636e-05
# country_MOZ                               9.01939e-06
# country_ABW                               0
# country_AIA                               0
# country_ALB                               0
# country_AND                               0
# country_ARM                               0
# country_ASM                               0
# country_ATA                               0
# country_ATF                               0
# country_AZE                               0
# country_BDI                               0
# country_BEN                               0
# country_BFA                               0
# country_BGD                               0
# country_BHR                               0
# country_BHS                               0
# country_BIH                               0
# country_BLR                               0
# country_BOL                               0
# country_BRB                               0
# country_BWA                               0
# country_CAF                               0
# country_CIV                               0
# country_CMR                               0
# country_COM                               0
# country_CRI                               0
# country_CUB                               0
# country_CYM                               0
# country_CYP                               0
# country_DJI                               0
# country_DMA                               0
# country_DOM                               0
# country_EST                               0
# country_ETH                               0
# country_FJI                               0
# country_FRO                               0
# country_GAB                               0
# country_GEO                               0
# country_GHA                               0
# country_GLP                               0
# country_GTM                               0
# country_GUY                               0
# country_HND                               0
# country_IMN                               0
# country_IRQ                               0
# country_ISL                               0
# country_JAM                               0
# country_JOR                               0
# country_KEN                               0
# country_KHM                               0
# country_KIR                               0
# country_KNA                               0
# country_KWT                               0
# country_LAO                               0
# country_LBN                               0
# country_LBY                               0
# country_LCA                               0
# country_LIE                               0
# country_LKA                               0
# country_LTU                               0
# country_LVA                               0
# country_MCO                               0
# country_MDG                               0
# country_MLI                               0
# country_MLT                               0
# country_MMR                               0
# country_MNE                               0
# country_MRT                               0
# country_MUS                               0
# country_MWI                               0
# country_MYS                               0
# country_MYT                               0
# country_NAM                               0
# country_NCL                               0
# country_NIC                               0
# country_NPL                               0
# country_NZL                               0
# country_PAN                               0
# country_PLW                               0
# country_PRI                               0
# country_PRY                               0
# country_PYF                               0
# country_RWA                               0
# country_SDN                               0
# country_SEN                               0
# country_SLE                               0
# country_SLV                               0
# country_SMR                               0
# country_SRB                               0
# country_STP                               0
# country_SUR                               0
# country_SVN                               0
# country_SYC                               0
# country_SYR                               0
# country_TGO                               0
# country_TJK                               0
# country_TMP                               0
# country_UGA                               0
# country_UKR                               0
# country_URY                               0
# country_UZB                               0
# country_VGB                               0
# country_VNM                               0
# distribution_channel_Undefined            0
# customer_type_Group                       0

# %%
top50_feature_dt = [item[0] for item in values_dt[:50]]

# %%
X_train_dt=X_train[top50_feature_dt]
X_test_dt=X_test[top50_feature_dt]

# %%
clf_dt.fit(X_train_dt, y_train)
# Out:
# DecisionTreeClassifier(random_state=47)

# %%
y_pred3 = clf_dt.predict(X_test_dt)

# %%
print (confusion_matrix(y_test, y_pred3))
print (classification_report(y_test, y_pred3))
# Out:
# [[21061   824]
#  [  845 12356]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     21885
#            1       0.94      0.94      0.94     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.95      0.95      0.95     35086
# weighted avg       0.95      0.95      0.95     35086

# %%
top100_feature_dt = [item[0] for item in values_dt[:100]]
X_train_dt=X_train[top100_feature_dt]
X_test_dt=X_test[top100_feature_dt]

# %%
clf_dt.fit(X_train_dt, y_train)
y_pred3 = clf_dt.predict(X_test_dt)

# %%
print (confusion_matrix(y_test, y_pred3))
print (classification_report(y_test, y_pred3))
# Out:
# [[21056   829]
#  [  897 12304]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     21885
#            1       0.94      0.93      0.93     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.95      0.95      0.95     35086
# weighted avg       0.95      0.95      0.95     35086

# %%
top25_feature_dt = [item[0] for item in values_dt[:25]]
X_train_dt=X_train[top25_feature_dt]
X_test_dt=X_test[top25_feature_dt]

# %%
clf_dt.fit(X_train_dt, y_train)
y_pred3 = clf_dt.predict(X_test_dt)

# %%
print (confusion_matrix(y_test, y_pred3))
print (classification_report(y_test, y_pred3))
# Out:
# [[21047   838]
#  [  884 12317]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     21885
#            1       0.94      0.93      0.93     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.95      0.95      0.95     35086
# weighted avg       0.95      0.95      0.95     35086

# %% [markdown]
# ### Gradient Boosting

# %%
clf_gb = GradientBoostingClassifier(random_state = 47)

clf_gb.fit(X_train, y_train)
y_pred_gb = clf_gb.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_gb))
print (classification_report(y_test, y_pred_gb))
# Out:
# [[20962   923]
#  [ 2554 10647]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.96      0.92     21885
#            1       0.92      0.81      0.86     13201
#
#     accuracy                           0.90     35086
#    macro avg       0.91      0.88      0.89     35086
# weighted avg       0.90      0.90      0.90     35086

# %% [markdown]
# #### Feature Importance - Gradient Boosting

# %%
headers = ["name", "score"]
values_gb = sorted(zip(X_train.columns, clf_gb.feature_importances_), key=lambda x: x[1] * -1)
print('Feature Importance - Gradient Boosting')
print(tabulate(values_gb, headers, tablefmt="plain"))
# Out:
# Feature Importance - Gradient Boosting
# name                                            score
# deposit_type_Non Refund                   0.340067
# country_PRT                               0.0925429
# lead_time                                 0.0819307
# market_segment_Online TA                  0.0736457
# total_of_special_requests                 0.0588768
# reservation_status_date_month             0.0367448
# arrival_date_month                        0.0328232
# arrival_date_week_number                  0.0306488
# required_car_parking_spaces               0.0304181
# previous_cancellations                    0.0277206
# reservation_status_day_of_week_Sunday     0.0268049
# stays_in_week_nights                      0.0241976
# stays_in_weekend_nights                   0.0226044
# agent                                     0.0173813
# reservation_status_date_year              0.0170523
# booking_changes                           0.015071
# customer_type_Transient                   0.0121362
# arrival_date_year                         0.0118545
# previous_bookings_not_canceled            0.00975803
# reservation_status_day_of_week_Tuesday    0.00500644
# adr                                       0.00486067
# country_DEU                               0.00373
# reserved_room_type_A                      0.00338202
# arrival_date_day_of_week_Saturday         0.00284305
# deposit_type_No Deposit                   0.00284216
# assigned_room_type_A                      0.00259966
# reservation_status_day_of_week_Saturday   0.0023496
# country_AGO                               0.00168969
# customer_type_Transient-Party             0.00147163
# market_segment_Direct                     0.000948341
# market_segment_Offline TA/TO              0.000912264
# country_FRA                               0.000666139
# country_ESP                               0.000488066
# adults                                    0.000458011
# distribution_channel_TA/TO                0.000455337
# country_ITA                               0.000420079
# reservation_status_day_of_week_Friday     0.000382897
# arrival_date_day_of_week_Tuesday          0.000368813
# meal_Undefined                            0.000366876
# arrival_date_day_of_week_Friday           0.000298492
# country_CHN                               0.000239391
# market_segment_Corporate                  0.000194971
# reservation_status_day_of_week_Monday     0.000170227
# country_TUR                               0.000140807
# country_BEL                               0.000102741
# assigned_room_type_B                      9.10134e-05
# days_in_waiting_list                      5.70851e-05
# reservation_status_date_day               4.85531e-05
# country_FRO                               3.7296e-05
# country_PHL                               3.55619e-05
# market_segment_Aviation                   3.06018e-05
# children                                  1.92726e-05
# reservation_status_day_of_week_Thursday   1.36838e-05
# arrival_date_day                          0
# babies                                    0
# is_repeated_guest                         0
# hotel_City Hotel                          0
# hotel_Resort Hotel                        0
# arrival_date_day_of_week_Monday           0
# arrival_date_day_of_week_Sunday           0
# arrival_date_day_of_week_Thursday         0
# arrival_date_day_of_week_Wednesday        0
# meal_BB                                   0
# meal_FB                                   0
# meal_HB                                   0
# meal_SC                                   0
# country_ABW                               0
# country_AIA                               0
# country_ALB                               0
# country_AND                               0
# country_ARE                               0
# country_ARG                               0
# country_ARM                               0
# country_ASM                               0
# country_ATA                               0
# country_ATF                               0
# country_AUS                               0
# country_AUT                               0
# country_AZE                               0
# country_BDI                               0
# country_BEN                               0
# country_BFA                               0
# country_BGD                               0
# country_BGR                               0
# country_BHR                               0
# country_BHS                               0
# country_BIH                               0
# country_BLR                               0
# country_BOL                               0
# country_BRA                               0
# country_BRB                               0
# country_BWA                               0
# country_CAF                               0
# country_CHE                               0
# country_CHL                               0
# country_CIV                               0
# country_CMR                               0
# country_CN                                0
# country_COL                               0
# country_COM                               0
# country_CPV                               0
# country_CRI                               0
# country_CUB                               0
# country_CYM                               0
# country_CYP                               0
# country_CZE                               0
# country_DJI                               0
# country_DMA                               0
# country_DNK                               0
# country_DOM                               0
# country_DZA                               0
# country_ECU                               0
# country_EGY                               0
# country_EST                               0
# country_ETH                               0
# country_FIN                               0
# country_FJI                               0
# country_GAB                               0
# country_GBR                               0
# country_GEO                               0
# country_GGY                               0
# country_GHA                               0
# country_GIB                               0
# country_GLP                               0
# country_GNB                               0
# country_GRC                               0
# country_GTM                               0
# country_GUY                               0
# country_HKG                               0
# country_HND                               0
# country_HRV                               0
# country_HUN                               0
# country_IDN                               0
# country_IMN                               0
# country_IND                               0
# country_IRL                               0
# country_IRN                               0
# country_IRQ                               0
# country_ISL                               0
# country_ISR                               0
# country_JAM                               0
# country_JEY                               0
# country_JOR                               0
# country_JPN                               0
# country_KAZ                               0
# country_KEN                               0
# country_KHM                               0
# country_KIR                               0
# country_KNA                               0
# country_KOR                               0
# country_KWT                               0
# country_LAO                               0
# country_LBN                               0
# country_LBY                               0
# country_LCA                               0
# country_LIE                               0
# country_LKA                               0
# country_LTU                               0
# country_LUX                               0
# country_LVA                               0
# country_MAC                               0
# country_MAR                               0
# country_MCO                               0
# country_MDG                               0
# country_MDV                               0
# country_MEX                               0
# country_MKD                               0
# country_MLI                               0
# country_MLT                               0
# country_MMR                               0
# country_MNE                               0
# country_MOZ                               0
# country_MRT                               0
# country_MUS                               0
# country_MWI                               0
# country_MYS                               0
# country_MYT                               0
# country_NAM                               0
# country_NCL                               0
# country_NGA                               0
# country_NIC                               0
# country_NLD                               0
# country_NOR                               0
# country_NPL                               0
# country_NZL                               0
# country_OMN                               0
# country_PAK                               0
# country_PAN                               0
# country_PER                               0
# country_PLW                               0
# country_POL                               0
# country_PRI                               0
# country_PRY                               0
# country_PYF                               0
# country_QAT                               0
# country_ROU                               0
# country_RUS                               0
# country_RWA                               0
# country_SAU                               0
# country_SDN                               0
# country_SEN                               0
# country_SGP                               0
# country_SLE                               0
# country_SLV                               0
# country_SMR                               0
# country_SRB                               0
# country_STP                               0
# country_SUR                               0
# country_SVK                               0
# country_SVN                               0
# country_SWE                               0
# country_SYC                               0
# country_SYR                               0
# country_TGO                               0
# country_THA                               0
# country_TJK                               0
# country_TMP                               0
# country_TUN                               0
# country_TWN                               0
# country_TZA                               0
# country_UGA                               0
# country_UKR                               0
# country_UMI                               0
# country_URY                               0
# country_USA                               0
# country_UZB                               0
# country_VEN                               0
# country_VGB                               0
# country_VNM                               0
# country_ZAF                               0
# country_ZMB                               0
# country_ZWE                               0
# country_not available                     0
# market_segment_Complementary              0
# market_segment_Groups                     0
# distribution_channel_Corporate            0
# distribution_channel_Direct               0
# distribution_channel_GDS                  0
# distribution_channel_Undefined            0
# reserved_room_type_B                      0
# reserved_room_type_C                      0
# reserved_room_type_D                      0
# reserved_room_type_E                      0
# reserved_room_type_F                      0
# reserved_room_type_G                      0
# reserved_room_type_H                      0
# reserved_room_type_L                      0
# assigned_room_type_C                      0
# assigned_room_type_D                      0
# assigned_room_type_E                      0
# assigned_room_type_F                      0
# assigned_room_type_G                      0
# assigned_room_type_H                      0
# assigned_room_type_I                      0
# assigned_room_type_K                      0
# deposit_type_Refundable                   0
# customer_type_Contract                    0
# customer_type_Group                       0
# reservation_status_day_of_week_Wednesday  0

# %% [markdown]
# ### Random Forest

# %%
rf = RandomForestClassifier(random_state=47)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_rf))
print (classification_report(y_test, y_pred_rf))
# Out:
# [[21654   231]
#  [ 1461 11740]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     21885
#            1       0.98      0.89      0.93     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.96      0.94      0.95     35086
# weighted avg       0.95      0.95      0.95     35086

# %% [markdown]
# #### Feature Importance - RF

# %%
headers = ["name", "score"]
values_rf = sorted(zip(X_train.columns, rf.feature_importances_), key=lambda x: x[1] * -1)
print('Feature Importance - Random Forest')
print(tabulate(values_rf, headers, tablefmt="plain"))
# Out:
# Feature Importance - Random Forest
# name                                            score
# lead_time                                 0.0692112
# deposit_type_Non Refund                   0.062218
# country_PRT                               0.0586881
# reservation_status_date_month             0.0577651
# deposit_type_No Deposit                   0.049818
# total_of_special_requests                 0.0440357
# arrival_date_week_number                  0.0432837
# adr                                       0.0396664
# reservation_status_date_day               0.0368257
# arrival_date_month                        0.0338692
# arrival_date_day                          0.0328172
# agent                                     0.030052
# stays_in_week_nights                      0.0272971
# stays_in_weekend_nights                   0.0235854
# previous_cancellations                    0.0225817
# reservation_status_date_year              0.017155
# required_car_parking_spaces               0.0167015
# market_segment_Online TA                  0.0163829
# reservation_status_day_of_week_Sunday     0.0147776
# arrival_date_year                         0.014354
# booking_changes                           0.0139562
# market_segment_Groups                     0.0124718
# customer_type_Transient                   0.0118533
# assigned_room_type_A                      0.00963607
# market_segment_Offline TA/TO              0.00952477
# customer_type_Transient-Party             0.00930498
# reservation_status_day_of_week_Tuesday    0.00870554
# reservation_status_day_of_week_Monday     0.00810299
# distribution_channel_TA/TO                0.00809804
# adults                                    0.00792909
# reservation_status_day_of_week_Saturday   0.00765546
# arrival_date_day_of_week_Friday           0.00690485
# reservation_status_day_of_week_Wednesday  0.00690246
# reservation_status_day_of_week_Friday     0.00686227
# reservation_status_day_of_week_Thursday   0.00675382
# hotel_City Hotel                          0.00654378
# arrival_date_day_of_week_Saturday         0.00640207
# arrival_date_day_of_week_Monday           0.00602976
# arrival_date_day_of_week_Thursday         0.00600895
# market_segment_Direct                     0.00590148
# assigned_room_type_D                      0.00573464
# reserved_room_type_A                      0.00556725
# country_GBR                               0.00556576
# arrival_date_day_of_week_Wednesday        0.00541934
# country_FRA                               0.00538269
# arrival_date_day_of_week_Sunday           0.00480685
# meal_BB                                   0.00480488
# arrival_date_day_of_week_Tuesday          0.00472555
# hotel_Resort Hotel                        0.00466205
# country_DEU                               0.00446606
# distribution_channel_Direct               0.00424908
# children                                  0.0038613
# country_ESP                               0.00373298
# reserved_room_type_D                      0.00351344
# meal_HB                                   0.00346113
# previous_bookings_not_canceled            0.00328079
# meal_SC                                   0.00300434
# distribution_channel_Corporate            0.00213368
# country_ITA                               0.00207905
# days_in_waiting_list                      0.00200874
# assigned_room_type_E                      0.00200364
# country_IRL                               0.00174653
# is_repeated_guest                         0.00172355
# country_BRA                               0.00167684
# reserved_room_type_E                      0.00161392
# market_segment_Corporate                  0.00158784
# customer_type_Contract                    0.0014544
# country_BEL                               0.0013
# assigned_room_type_F                      0.00121621
# country_NLD                               0.00120224
# country_CHN                               0.00118872
# country_USA                               0.00114731
# country_CHE                               0.00114366
# assigned_room_type_B                      0.000998619
# reserved_room_type_G                      0.000958759
# reserved_room_type_F                      0.000953849
# assigned_room_type_G                      0.000916376
# assigned_room_type_C                      0.000903834
# country_CN                                0.000902761
# country_AUT                               0.000840832
# country_AGO                               0.000800284
# country_SWE                               0.00072628
# meal_Undefined                            0.000665399
# country_RUS                               0.000600582
# reserved_room_type_B                      0.000587406
# country_POL                               0.000580875
# meal_FB                                   0.000549375
# babies                                    0.000507878
# country_ISR                               0.000504354
# country_NOR                               0.000463291
# reserved_room_type_C                      0.000435123
# country_ROU                               0.000408782
# country_MAR                               0.000393719
# country_AUS                               0.000345082
# country_LUX                               0.000341295
# country_HUN                               0.000340994
# country_TUR                               0.000329033
# reserved_room_type_H                      0.00030894
# assigned_room_type_H                      0.000306176
# country_FIN                               0.000302952
# country_DNK                               0.000276655
# country_not available                     0.000230193
# deposit_type_Refundable                   0.000225305
# customer_type_Group                       0.000222927
# market_segment_Aviation                   0.000222557
# country_KOR                               0.000169757
# country_IRN                               0.000157979
# country_CZE                               0.00014894
# country_ARG                               0.000141959
# country_PHL                               0.000139525
# country_SAU                               0.000136944
# country_ARE                               0.000128756
# country_JPN                               0.000122745
# country_GRC                               0.000120783
# country_ZAF                               0.000120164
# country_COL                               0.000120052
# country_HKG                               0.000118145
# distribution_channel_GDS                  0.000116328
# assigned_room_type_K                      0.000115856
# country_NGA                               0.000111806
# country_IND                               0.000106728
# country_DZA                               0.000103502
# country_THA                               0.000102147
# country_MOZ                               9.94341e-05
# country_NZL                               9.36465e-05
# country_TUN                               8.39318e-05
# country_SGP                               7.65367e-05
# country_IDN                               7.58855e-05
# country_GIB                               7.47838e-05
# country_BGR                               7.03392e-05
# country_HRV                               6.96789e-05
# country_MAC                               6.95122e-05
# country_SVK                               6.7192e-05
# country_EST                               6.62078e-05
# country_TWN                               6.42361e-05
# country_VEN                               6.33098e-05
# country_LTU                               5.56951e-05
# assigned_room_type_I                      5.46462e-05
# country_SVN                               5.33268e-05
# country_MEX                               5.30474e-05
# country_ECU                               4.98334e-05
# country_MLT                               4.939e-05
# country_CHL                               4.84789e-05
# country_UKR                               4.75108e-05
# country_LBN                               4.65166e-05
# country_PER                               4.61351e-05
# country_QAT                               4.18925e-05
# country_GEO                               4.15548e-05
# country_ISL                               4.07348e-05
# country_LVA                               3.74072e-05
# country_DOM                               3.48832e-05
# country_MKD                               3.46717e-05
# country_MDV                               3.22559e-05
# country_JEY                               3.15038e-05
# country_KWT                               3.12866e-05
# country_AZE                               3.07696e-05
# country_CYP                               2.93174e-05
# country_EGY                               2.85169e-05
# country_PAK                               2.69178e-05
# country_KAZ                               2.67374e-05
# country_SRB                               2.58826e-05
# country_OMN                               2.48452e-05
# country_BLR                               2.46847e-05
# country_TZA                               2.41784e-05
# country_CPV                               2.33167e-05
# country_BGD                               2.19857e-05
# country_URY                               2.05352e-05
# country_MYS                               2.03069e-05
# country_GGY                               1.60106e-05
# country_BIH                               1.51301e-05
# market_segment_Complementary              1.36939e-05
# country_GLP                               1.35456e-05
# country_SEN                               1.28533e-05
# country_GAB                               1.26235e-05
# country_NAM                               1.25468e-05
# country_ZWE                               1.18028e-05
# country_PAN                               1.09121e-05
# country_ZMB                               1.08811e-05
# country_FRO                               9.97237e-06
# country_BEN                               9.53408e-06
# country_CIV                               9.04639e-06
# country_ALB                               8.78277e-06
# country_AND                               8.57354e-06
# country_BHR                               8.54648e-06
# reserved_room_type_L                      8.47263e-06
# country_UMI                               7.45013e-06
# country_ARM                               7.13867e-06
# country_CRI                               7.10518e-06
# country_MCO                               6.76898e-06
# country_TMP                               6.65674e-06
# country_PRI                               6.57107e-06
# country_JOR                               6.29962e-06
# country_GNB                               5.90803e-06
# country_VNM                               5.62487e-06
# country_SUR                               5.06019e-06
# country_LIE                               4.69565e-06
# country_TJK                               4.66452e-06
# country_MNE                               4.65913e-06
# country_NIC                               4.63454e-06
# country_PRY                               4.60282e-06
# country_TGO                               4.54425e-06
# country_BOL                               3.75787e-06
# country_KEN                               3.56416e-06
# country_ETH                               3.19503e-06
# country_IRQ                               3.03471e-06
# country_KHM                               2.96044e-06
# country_CMR                               2.80153e-06
# country_COM                               2.70873e-06
# country_JAM                               2.58231e-06
# country_UZB                               2.46391e-06
# country_ATF                               2.03172e-06
# country_AIA                               1.9385e-06
# country_LKA                               1.82525e-06
# country_VGB                               1.37798e-06
# country_LBY                               1.36907e-06
# country_SLV                               1.18184e-06
# country_GTM                               1.13538e-06
# country_SYR                               1.10876e-06
# country_GHA                               1.08985e-06
# country_CUB                               1.04843e-06
# country_BWA                               1.02909e-06
# country_DMA                               9.80834e-07
# country_ATA                               8.63206e-07
# country_BFA                               8.39562e-07
# country_MUS                               7.33106e-07
# country_MWI                               6.98004e-07
# country_ASM                               6.33571e-07
# country_FJI                               6.24253e-07
# country_MRT                               5.2418e-07
# country_RWA                               3.90459e-07
# country_LCA                               3.48138e-07
# country_STP                               3.04726e-07
# country_LAO                               2.86889e-07
# country_BHS                               2.61162e-07
# country_SYC                               2.44631e-07
# country_ABW                               2.17444e-07
# country_KNA                               2.05561e-07
# country_SDN                               1.75065e-07
# distribution_channel_Undefined            1.68036e-07
# country_SMR                               3.63496e-08
# country_MYT                               2.8927e-08
# country_BRB                               2.78211e-08
# country_CAF                               2.17555e-08
# country_MLI                               1.95945e-08
# country_MDG                               1.37358e-08
# country_MMR                               1.33746e-08
# country_BDI                               0
# country_CYM                               0
# country_DJI                               0
# country_GUY                               0
# country_HND                               0
# country_IMN                               0
# country_KIR                               0
# country_NCL                               0
# country_NPL                               0
# country_PLW                               0
# country_PYF                               0
# country_SLE                               0
# country_UGA                               0

# %%
# top 50 features 

top50_feature_rf = [item[0] for item in values_rf[:50]]

# %%
X_train_rf=X_train[top50_feature_rf]
X_test_rf=X_test [top50_feature_rf]

# %%
rf.fit(X_train_rf, y_train)
# Out:
# RandomForestClassifier(random_state=47)

# %%
y_pred2 = rf.predict(X_test_rf)

# %%
print (confusion_matrix(y_test, y_pred2))
print (classification_report(y_test, y_pred2))
# Out:
# [[21646   239]
#  [ 1155 12046]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     21885
#            1       0.98      0.91      0.95     13201
#
#     accuracy                           0.96     35086
#    macro avg       0.96      0.95      0.96     35086
# weighted avg       0.96      0.96      0.96     35086

# %%
# top 100 features

top100_feature_rf = [item[0] for item in values_rf[:100]]

# %%
X_train_rf=X_train[top100_feature_rf]
X_test_rf=X_test [top100_feature_rf]

# %%
rf.fit(X_train_rf, y_train)
# Out:
# RandomForestClassifier(random_state=47)

# %%
y_pred2 = rf.predict(X_test_rf)

# %%
# top 100 features

print (confusion_matrix(y_test, y_pred2))
print (classification_report(y_test, y_pred2))
# Out:
# [[21629   256]
#  [ 1319 11882]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     21885
#            1       0.98      0.90      0.94     13201
#
#     accuracy                           0.96     35086
#    macro avg       0.96      0.94      0.95     35086
# weighted avg       0.96      0.96      0.95     35086

# %%
# top 20

top20_feature_rf = [item[0] for item in values_rf[:20]]

# %%
X_train_rf=X_train[top20_feature_rf]
X_test_rf=X_test [top20_feature_rf]

# %%
rf.fit(X_train_rf, y_train)
y_pred2 = rf.predict(X_test_rf)

# %%
# top 20 features

print (confusion_matrix(y_test, y_pred2))
print (classification_report(y_test, y_pred2))
# Out:
# [[21717   168]
#  [  951 12250]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     21885
#            1       0.99      0.93      0.96     13201
#
#     accuracy                           0.97     35086
#    macro avg       0.97      0.96      0.97     35086
# weighted avg       0.97      0.97      0.97     35086

# %% [markdown]
# ### Refine the Decision Tree Model (Tuning Parameters)

# %%
param_grid_dt ={
    "criterion":['gini','entropy'],
    "max_depth":range(70, 200),
    "min_samples_split":range(1,10),
    "min_samples_leaf":range(1,10)
}

# %%
# Randomized Search

random_dt = RandomizedSearchCV(clf_dt, param_distributions = param_grid_dt, cv=5, verbose=1, n_jobs=-1, n_iter=200)

random_dt.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed: 19.6min finished
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=47),
#                    n_iter=200, n_jobs=-1,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(70, 200),
#                                         'min_samples_leaf': range(1, 10),
#                                         'min_samples_split': range(1, 10)},
#                    verbose=1)

# %%
random_dt.best_params_
# Out:
# {'min_samples_split': 6,
#  'min_samples_leaf': 2,
#  'max_depth': 135,
#  'criterion': 'entropy'}

# %%
### Grid Search

# %%
param_grid ={
    "criterion":['gini','entropy'],
    "max_depth":range(140, 175),
    "min_samples_split":range(3,8),
    "min_samples_leaf":range(1,5)
}

# %%
grid_dt = GridSearchCV(clf_dt, param_grid = param_grid, cv=5, verbose=1, n_jobs=-1)

grid_dt.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1400 candidates, totalling 7000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done 1242 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done 1792 tasks      | elapsed: 101.1min
# [Parallel(n_jobs=-1)]: Done 2442 tasks      | elapsed: 118.8min
# [Parallel(n_jobs=-1)]: Done 3192 tasks      | elapsed: 135.8min
# [Parallel(n_jobs=-1)]: Done 4042 tasks      | elapsed: 153.8min
# [Parallel(n_jobs=-1)]: Done 4992 tasks      | elapsed: 172.5min
# [Parallel(n_jobs=-1)]: Done 6042 tasks      | elapsed: 194.3min
# [Parallel(n_jobs=-1)]: Done 7000 out of 7000 | elapsed: 215.7min finished
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=47), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(140, 175),
#                          'min_samples_leaf': range(1, 5),
#                          'min_samples_split': range(3, 8)},
#              verbose=1)

# %%
grid_dt.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 140,
#  'min_samples_leaf': 1,
#  'min_samples_split': 3}

# %% [markdown]
# #### implementing optimized parameters to Decision Tree Model

# %%
clf_dt2 = tree.DecisionTreeClassifier(criterion='entropy',max_depth=140, 
                                     min_samples_leaf=1, min_samples_split=3, random_state=47)

clf_dt2.fit(X_train, y_train)
y_pred_dt2 = clf_dt2.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_dt2))
print (classification_report(y_test, y_pred_dt2))
# Out:
# [[21166   719]
#  [  823 12378]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     21885
#            1       0.95      0.94      0.94     13201
#
#     accuracy                           0.96     35086
#    macro avg       0.95      0.95      0.95     35086
# weighted avg       0.96      0.96      0.96     35086

# %%
headers = ["name", "score"]
values_dt = sorted(zip(X_train.columns, clf_dt2.feature_importances_), key=lambda x: x[1] * -1)
print('Feature Importance - Decision Tree (hyperparameter tuning)')
print(tabulate(values_dt, headers, tablefmt="plain"))
# Out:
# Feature Importance - Decision Tree (hyperparameter tuning)
# name                                            score
# deposit_type_Non Refund                   0.199373
# arrival_date_week_number                  0.0816116
# market_segment_Online TA                  0.0703453
# reservation_status_date_month             0.0681787
# reservation_status_date_day               0.0592259
# lead_time                                 0.0582863
# arrival_date_month                        0.0481972
# agent                                     0.0400916
# total_of_special_requests                 0.0379441
# arrival_date_day                          0.0363977
# country_PRT                               0.0313628
# required_car_parking_spaces               0.0311332
# arrival_date_year                         0.0228228
# reservation_status_date_year              0.0220665
# reservation_status_day_of_week_Sunday     0.017502
# adr                                       0.0160532
# previous_cancellations                    0.0150817
# stays_in_week_nights                      0.0146223
# stays_in_weekend_nights                   0.0127602
# customer_type_Transient                   0.00987116
# market_segment_Direct                     0.00751992
# previous_bookings_not_canceled            0.0055278
# reservation_status_day_of_week_Saturday   0.00546246
# reservation_status_day_of_week_Friday     0.00506674
# reservation_status_day_of_week_Thursday   0.00454908
# booking_changes                           0.00419238
# country_DEU                               0.00403257
# reservation_status_day_of_week_Wednesday  0.00387136
# reservation_status_day_of_week_Monday     0.00381738
# customer_type_Transient-Party             0.00376363
# reservation_status_day_of_week_Tuesday    0.00373457
# country_ITA                               0.00331907
# adults                                    0.00285208
# arrival_date_day_of_week_Sunday           0.00275673
# arrival_date_day_of_week_Friday           0.00258848
# arrival_date_day_of_week_Thursday         0.0025774
# arrival_date_day_of_week_Wednesday        0.00222133
# arrival_date_day_of_week_Saturday         0.002153
# market_segment_Corporate                  0.00199539
# arrival_date_day_of_week_Monday           0.00190372
# meal_Undefined                            0.00187396
# assigned_room_type_A                      0.00186821
# arrival_date_day_of_week_Tuesday          0.00149075
# country_ESP                               0.00146013
# country_AGO                               0.00132048
# market_segment_Groups                     0.00127499
# distribution_channel_TA/TO                0.00112688
# assigned_room_type_D                      0.00105738
# reserved_room_type_D                      0.000984828
# country_GBR                               0.000982762
# meal_BB                                   0.000882087
# meal_HB                                   0.000855475
# children                                  0.000801906
# hotel_Resort Hotel                        0.000769887
# country_USA                               0.000739596
# country_BRA                               0.000676937
# reserved_room_type_B                      0.00067426
# assigned_room_type_E                      0.000651381
# reserved_room_type_E                      0.000638372
# meal_SC                                   0.000632527
# reserved_room_type_A                      0.000627642
# country_not available                     0.000529783
# distribution_channel_Direct               0.000523547
# country_FRA                               0.000486563
# market_segment_Offline TA/TO              0.000447385
# days_in_waiting_list                      0.000432212
# assigned_room_type_C                      0.000428287
# is_repeated_guest                         0.000386558
# hotel_City Hotel                          0.000356542
# country_LUX                               0.000329174
# country_CN                                0.000312893
# country_IRL                               0.000309022
# country_CHN                               0.000300303
# country_NGA                               0.000290324
# country_RUS                               0.000285091
# assigned_room_type_B                      0.000282469
# customer_type_Contract                    0.000277581
# assigned_room_type_F                      0.000277159
# meal_FB                                   0.000273582
# country_BEL                               0.000260978
# assigned_room_type_G                      0.000242273
# babies                                    0.000240836
# distribution_channel_Corporate            0.000232818
# country_ROU                               0.000228667
# reserved_room_type_C                      0.000210107
# country_MAR                               0.000193831
# country_IDN                               0.000192524
# country_AUT                               0.000187049
# country_CHE                               0.000183973
# country_FIN                               0.000180897
# country_SWE                               0.000174873
# market_segment_Aviation                   0.000170187
# country_TUR                               0.00015648
# reserved_room_type_F                      0.000150933
# country_NLD                               0.000150139
# reserved_room_type_H                      0.000146843
# country_SAU                               0.000143022
# country_OMN                               0.000129015
# country_CZE                               0.000123756
# country_TUN                               0.000122264
# country_MOZ                               0.000112143
# reserved_room_type_G                      0.000106575
# assigned_room_type_K                      0.000102145
# country_POL                               9.85607e-05
# country_AZE                               9.43067e-05
# country_IRN                               9.22275e-05
# country_BGR                               8.63915e-05
# country_HRV                               8.41201e-05
# country_NOR                               8.23778e-05
# deposit_type_No Deposit                   7.83342e-05
# country_HKG                               6.11376e-05
# customer_type_Group                       5.57335e-05
# country_SGP                               5.56879e-05
# country_MLT                               5.28783e-05
# country_ZAF                               5.23044e-05
# country_PAK                               5.12235e-05
# country_THA                               4.45228e-05
# country_SVK                               4.00027e-05
# country_PER                               3.89821e-05
# country_ECU                               3.80286e-05
# country_ABW                               0
# country_AIA                               0
# country_ALB                               0
# country_AND                               0
# country_ARE                               0
# country_ARG                               0
# country_ARM                               0
# country_ASM                               0
# country_ATA                               0
# country_ATF                               0
# country_AUS                               0
# country_BDI                               0
# country_BEN                               0
# country_BFA                               0
# country_BGD                               0
# country_BHR                               0
# country_BHS                               0
# country_BIH                               0
# country_BLR                               0
# country_BOL                               0
# country_BRB                               0
# country_BWA                               0
# country_CAF                               0
# country_CHL                               0
# country_CIV                               0
# country_CMR                               0
# country_COL                               0
# country_COM                               0
# country_CPV                               0
# country_CRI                               0
# country_CUB                               0
# country_CYM                               0
# country_CYP                               0
# country_DJI                               0
# country_DMA                               0
# country_DNK                               0
# country_DOM                               0
# country_DZA                               0
# country_EGY                               0
# country_EST                               0
# country_ETH                               0
# country_FJI                               0
# country_FRO                               0
# country_GAB                               0
# country_GEO                               0
# country_GGY                               0
# country_GHA                               0
# country_GIB                               0
# country_GLP                               0
# country_GNB                               0
# country_GRC                               0
# country_GTM                               0
# country_GUY                               0
# country_HND                               0
# country_HUN                               0
# country_IMN                               0
# country_IND                               0
# country_IRQ                               0
# country_ISL                               0
# country_ISR                               0
# country_JAM                               0
# country_JEY                               0
# country_JOR                               0
# country_JPN                               0
# country_KAZ                               0
# country_KEN                               0
# country_KHM                               0
# country_KIR                               0
# country_KNA                               0
# country_KOR                               0
# country_KWT                               0
# country_LAO                               0
# country_LBN                               0
# country_LBY                               0
# country_LCA                               0
# country_LIE                               0
# country_LKA                               0
# country_LTU                               0
# country_LVA                               0
# country_MAC                               0
# country_MCO                               0
# country_MDG                               0
# country_MDV                               0
# country_MEX                               0
# country_MKD                               0
# country_MLI                               0
# country_MMR                               0
# country_MNE                               0
# country_MRT                               0
# country_MUS                               0
# country_MWI                               0
# country_MYS                               0
# country_MYT                               0
# country_NAM                               0
# country_NCL                               0
# country_NIC                               0
# country_NPL                               0
# country_NZL                               0
# country_PAN                               0
# country_PHL                               0
# country_PLW                               0
# country_PRI                               0
# country_PRY                               0
# country_PYF                               0
# country_QAT                               0
# country_RWA                               0
# country_SDN                               0
# country_SEN                               0
# country_SLE                               0
# country_SLV                               0
# country_SMR                               0
# country_SRB                               0
# country_STP                               0
# country_SUR                               0
# country_SVN                               0
# country_SYC                               0
# country_SYR                               0
# country_TGO                               0
# country_TJK                               0
# country_TMP                               0
# country_TWN                               0
# country_TZA                               0
# country_UGA                               0
# country_UKR                               0
# country_UMI                               0
# country_URY                               0
# country_UZB                               0
# country_VEN                               0
# country_VGB                               0
# country_VNM                               0
# country_ZMB                               0
# country_ZWE                               0
# market_segment_Complementary              0
# distribution_channel_GDS                  0
# distribution_channel_Undefined            0
# reserved_room_type_L                      0
# assigned_room_type_H                      0
# assigned_room_type_I                      0
# deposit_type_Refundable                   0

# %% [markdown]
# ### Refine the Random Forest Model (Tuning Parameters)

# %%
param_grid_rf = {
    'max_depth':[100,200,None],
    'max_features':['sqrt', 'log2'],
    'n_estimators':[100,500,1000]
}

# %%
grid_rf = GridSearchCV(rf, param_grid = param_grid_rf, cv=5, verbose= 1, n_jobs=-1)

grid_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 48.7min
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed: 100.5min finished
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=47), n_jobs=-1,
#              param_grid={'max_depth': [100, 200, None],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [100, 500, 1000]},
#              verbose=1)

# %%
grid_rf.best_params_
# Out:
# {'max_depth': 100, 'max_features': 'sqrt', 'n_estimators': 1000}

# %%
rf2 = RandomForestClassifier(max_depth=100,max_features='sqrt',n_estimators=1000,random_state=47)
rf2.fit(X_train, y_train)
y_pred_rf2 = rf2.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_rf2))
print (classification_report(y_test, y_pred_rf2))
# Out:
# [[21673   212]
#  [ 1416 11785]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     21885
#            1       0.98      0.89      0.94     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.96      0.94      0.95     35086
# weighted avg       0.96      0.95      0.95     35086

# %%
headers = ["name", "score"]
values_dt = sorted(zip(X_train.columns, rf2.feature_importances_), key=lambda x: x[1] * -1)
print('Feature Importance - Random Forest (hyperparameter tuning)')
print(tabulate(values_dt, headers, tablefmt="plain"))
# Out:
# Feature Importance - Random Forest (hyperparameter tuning)
# name                                            score
# lead_time                                 0.0682695
# deposit_type_Non Refund                   0.0604938
# country_PRT                               0.0580207
# deposit_type_No Deposit                   0.056613
# reservation_status_date_month             0.0554295
# arrival_date_week_number                  0.0434318
# total_of_special_requests                 0.0400311
# adr                                       0.0392294
# reservation_status_date_day               0.0372967
# arrival_date_day                          0.0326452
# arrival_date_month                        0.0324921
# agent                                     0.0301249
# stays_in_week_nights                      0.0282696
# stays_in_weekend_nights                   0.0245819
# previous_cancellations                    0.0234087
# market_segment_Online TA                  0.0168212
# required_car_parking_spaces               0.0166553
# reservation_status_date_year              0.0160977
# reservation_status_day_of_week_Sunday     0.0157675
# arrival_date_year                         0.0146062
# booking_changes                           0.0133333
# customer_type_Transient                   0.0127924
# market_segment_Groups                     0.0120759
# customer_type_Transient-Party             0.0103325
# assigned_room_type_A                      0.0103032
# market_segment_Offline TA/TO              0.00963041
# reservation_status_day_of_week_Tuesday    0.00864149
# reservation_status_day_of_week_Monday     0.00816989
# distribution_channel_TA/TO                0.00811383
# adults                                    0.00799955
# reservation_status_day_of_week_Saturday   0.00755054
# reservation_status_day_of_week_Friday     0.00719757
# reservation_status_day_of_week_Wednesday  0.00717164
# reservation_status_day_of_week_Thursday   0.00669352
# arrival_date_day_of_week_Friday           0.00652321
# arrival_date_day_of_week_Saturday         0.00628823
# arrival_date_day_of_week_Monday           0.00605067
# arrival_date_day_of_week_Thursday         0.00574435
# hotel_City Hotel                          0.00560602
# assigned_room_type_D                      0.00553367
# country_GBR                               0.0054483
# market_segment_Direct                     0.00544679
# hotel_Resort Hotel                        0.00544394
# reserved_room_type_A                      0.0054238
# arrival_date_day_of_week_Wednesday        0.00536712
# country_FRA                               0.00509624
# arrival_date_day_of_week_Sunday           0.00485351
# meal_BB                                   0.00483869
# arrival_date_day_of_week_Tuesday          0.00478689
# distribution_channel_Direct               0.00471745
# country_DEU                               0.00454815
# children                                  0.00398475
# country_ESP                               0.0036423
# meal_HB                                   0.00345491
# reserved_room_type_D                      0.0034372
# previous_bookings_not_canceled            0.00333274
# meal_SC                                   0.00297173
# country_ITA                               0.00213417
# days_in_waiting_list                      0.00199378
# assigned_room_type_E                      0.00196398
# distribution_channel_Corporate            0.0019584
# market_segment_Corporate                  0.0018662
# country_IRL                               0.00178945
# reserved_room_type_E                      0.00164969
# is_repeated_guest                         0.0016466
# country_BRA                               0.00164019
# customer_type_Contract                    0.00142301
# country_BEL                               0.00127167
# assigned_room_type_F                      0.00123307
# country_NLD                               0.00122026
# country_CHN                               0.00118917
# country_USA                               0.0011456
# country_CHE                               0.00112288
# assigned_room_type_B                      0.00100349
# reserved_room_type_F                      0.000942176
# assigned_room_type_G                      0.000901212
# assigned_room_type_C                      0.0008904
# country_CN                                0.000880334
# country_AUT                               0.000864271
# reserved_room_type_G                      0.000861069
# country_AGO                               0.000804518
# country_SWE                               0.000746149
# meal_Undefined                            0.000635467
# country_POL                               0.000607987
# country_RUS                               0.000607795
# reserved_room_type_B                      0.000587823
# meal_FB                                   0.000544501
# country_ISR                               0.000512847
# babies                                    0.000511629
# country_NOR                               0.000462194
# country_ROU                               0.000432011
# reserved_room_type_C                      0.000419814
# country_MAR                               0.000408903
# country_LUX                               0.000354437
# country_HUN                               0.000332746
# country_AUS                               0.000331921
# country_TUR                               0.000329531
# country_FIN                               0.000319263
# assigned_room_type_H                      0.000311248
# reserved_room_type_H                      0.000307535
# country_DNK                               0.000299935
# deposit_type_Refundable                   0.000234398
# market_segment_Aviation                   0.000208934
# customer_type_Group                       0.000208367
# country_not available                     0.000202391
# country_KOR                               0.000191095
# country_IRN                               0.000147738
# country_ARG                               0.00014734
# country_JPN                               0.000144179
# distribution_channel_GDS                  0.000140461
# country_CZE                               0.0001393
# country_ARE                               0.00013695
# country_GRC                               0.000136663
# country_PHL                               0.000129603
# country_HKG                               0.000128754
# country_SAU                               0.000128321
# country_ZAF                               0.000123826
# country_IND                               0.000122992
# country_COL                               0.000119236
# country_NGA                               0.000116871
# assigned_room_type_K                      0.00011179
# country_DZA                               0.000100562
# country_MOZ                               9.7815e-05
# country_THA                               9.53249e-05
# country_IDN                               9.14854e-05
# country_NZL                               8.40252e-05
# country_TUN                               8.37464e-05
# country_GIB                               8.16628e-05
# country_BGR                               7.87013e-05
# country_SVK                               7.59273e-05
# country_HRV                               7.2044e-05
# country_MAC                               7.17368e-05
# country_TWN                               6.69875e-05
# country_SGP                               6.59102e-05
# country_EST                               6.16256e-05
# country_VEN                               6.15579e-05
# assigned_room_type_I                      6.09892e-05
# country_CHL                               5.50942e-05
# country_MEX                               5.50767e-05
# country_LTU                               5.46381e-05
# country_ECU                               4.99125e-05
# country_SVN                               4.909e-05
# country_LBN                               4.65529e-05
# country_UKR                               4.56563e-05
# country_QAT                               4.47982e-05
# country_MLT                               4.3608e-05
# country_PER                               4.27001e-05
# country_KWT                               4.10747e-05
# country_LVA                               3.90135e-05
# country_GEO                               3.84714e-05
# country_AZE                               3.40704e-05
# country_CYP                               3.23954e-05
# country_MDV                               3.20147e-05
# country_SRB                               3.17913e-05
# country_ISL                               3.14699e-05
# country_MKD                               3.04057e-05
# country_JEY                               2.83468e-05
# country_DOM                               2.71009e-05
# country_KAZ                               2.65299e-05
# country_EGY                               2.57173e-05
# country_URY                               2.52797e-05
# country_OMN                               2.44406e-05
# country_BLR                               2.38233e-05
# country_MYS                               2.23579e-05
# country_TZA                               2.1899e-05
# country_CPV                               2.07516e-05
# country_BGD                               1.94155e-05
# country_PAK                               1.89773e-05
# country_GGY                               1.8233e-05
# country_ZWE                               1.5459e-05
# country_SEN                               1.49232e-05
# country_GLP                               1.49099e-05
# market_segment_Complementary              1.47811e-05
# country_PAN                               1.32712e-05
# country_GAB                               1.27879e-05
# country_AND                               1.25623e-05
# country_BIH                               1.24458e-05
# country_TJK                               1.17692e-05
# country_ZMB                               1.15755e-05
# reserved_room_type_L                      9.91136e-06
# country_CRI                               9.71954e-06
# country_TMP                               8.84084e-06
# country_NAM                               8.71271e-06
# country_ARM                               8.21717e-06
# country_FRO                               7.98545e-06
# country_UMI                               7.82576e-06
# country_ALB                               7.73911e-06
# country_JOR                               7.60508e-06
# country_BEN                               7.40298e-06
# country_GNB                               7.20611e-06
# country_CIV                               7.18579e-06
# country_BHR                               6.84683e-06
# country_SUR                               6.29812e-06
# country_VNM                               5.69995e-06
# country_LIE                               5.26642e-06
# country_PRI                               5.19054e-06
# country_MNE                               5.07787e-06
# country_MCO                               4.7817e-06
# country_PRY                               4.56323e-06
# country_COM                               4.29713e-06
# country_ETH                               4.18916e-06
# country_NIC                               4.02057e-06
# country_KEN                               3.8108e-06
# country_IRQ                               3.68504e-06
# country_CMR                               3.42462e-06
# country_KHM                               3.17896e-06
# country_TGO                               2.95381e-06
# country_ATF                               2.746e-06
# country_BOL                               2.45544e-06
# country_UZB                               2.1866e-06
# country_MUS                               2.02129e-06
# country_LBY                               1.9631e-06
# country_LKA                               1.5848e-06
# country_JAM                               1.51326e-06
# country_SYR                               1.48987e-06
# country_VGB                               1.48791e-06
# country_FJI                               1.40596e-06
# country_AIA                               1.38567e-06
# country_GTM                               1.16194e-06
# country_GHA                               1.09953e-06
# country_ASM                               1.03823e-06
# country_MRT                               8.73454e-07
# country_CUB                               7.21219e-07
# country_ATA                               6.6839e-07
# country_KNA                               5.7274e-07
# country_RWA                               5.65715e-07
# country_LCA                               5.29505e-07
# country_ABW                               5.25573e-07
# country_LAO                               5.15551e-07
# country_BWA                               4.70399e-07
# country_DMA                               4.41709e-07
# country_BHS                               4.18514e-07
# country_SLV                               4.09403e-07
# country_MYT                               3.81537e-07
# distribution_channel_Undefined            2.39917e-07
# country_CAF                               2.27454e-07
# country_BFA                               2.02802e-07
# country_MMR                               2.00524e-07
# country_NPL                               1.15181e-07
# country_SYC                               1.09581e-07
# country_MLI                               9.7811e-08
# country_SDN                               9.72663e-08
# country_SMR                               8.89937e-08
# country_MWI                               7.96331e-08
# country_CYM                               6.16156e-08
# country_STP                               5.9414e-08
# country_BRB                               4.54043e-08
# country_MDG                               2.16958e-08
# country_BDI                               0
# country_DJI                               0
# country_GUY                               0
# country_HND                               0
# country_IMN                               0
# country_KIR                               0
# country_NCL                               0
# country_PLW                               0
# country_PYF                               0
# country_SLE                               0
# country_UGA                               0

# %%
# Class imbalance doesn't change the model much 

clf_dt3 = tree.DecisionTreeClassifier(criterion='entropy',max_depth=140, 
                                     min_samples_leaf=1, min_samples_split=3, random_state=47,  class_weight={0:0.4,1:0.6})

clf_dt3.fit(X_train, y_train)
y_pred_dt3 = clf_dt3.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_dt3))
print (classification_report(y_test, y_pred_dt3))
# Out:
# [[21126   759]
#  [  791 12410]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     21885
#            1       0.94      0.94      0.94     13201
#
#     accuracy                           0.96     35086
#    macro avg       0.95      0.95      0.95     35086
# weighted avg       0.96      0.96      0.96     35086

# %%
# Class imbalance doesn't change the model

rf3 = RandomForestClassifier(max_depth=100,max_features='sqrt',n_estimators=1000,random_state=47, class_weight={0:0.4,1:0.6})
rf3.fit(X_train, y_train)
y_pred_rf3 = rf3.predict(X_test)

# %%
print (confusion_matrix(y_test, y_pred_rf3))
print (classification_report(y_test, y_pred_rf3))
# Out:
# [[21660   225]
#  [ 1411 11790]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     21885
#            1       0.98      0.89      0.94     13201
#
#     accuracy                           0.95     35086
#    macro avg       0.96      0.94      0.95     35086
# weighted avg       0.95      0.95      0.95     35086

# %% [markdown]
# Decision tree with criterion='entropy', max_depth=140, min_samples_leaf=1, min_samples_split=3, random_state=47

# %% [markdown]
# ## Create SHAP Explainer & Compute SHAP values

# %%
X_train.shape, X_test.shape
# Out:
# ((81865, 259), (35086, 259))

# %%
explainer = shap.TreeExplainer(clf_dt2, shap.sample(X_train,10000))
shap_values = explainer.shap_values(X_test)
# Out:
# Passing 10000 background samples may lead to slow runtimes. Consider using shap.sample(data, 100) to create a smaller background data set.
# 100%|===================| 70160/70172 [68:57<00:00]

# %% [markdown]
# ## Global Interpretation - Feature Importance Globally

# %%
shap.summary_plot(shap_values, X_test, plot_type='bar')

# %%
explainer.expected_value
# Out:
# array([0.62795, 0.37205])

# %% [markdown]
# ## Partial Dependence Plots

# %%
shap.dependence_plot(ind='country_PRT', interaction_index='country_PRT', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='deposit_type_Non Refund', interaction_index='deposit_type_Non Refund', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='reservation_status_date_month', interaction_index='reservation_status_date_month', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='market_segment_Online TA', interaction_index='market_segment_Online TA', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='lead_time', interaction_index='lead_time', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='agent', interaction_index='agent', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='arrival_date_year', interaction_index='arrival_date_year', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='arrival_date_week_number', interaction_index='arrival_date_week_number', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='reservation_status_date_year', interaction_index='reservation_status_date_year', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='reservation_status_date_day', interaction_index='reservation_status_date_day', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='required_car_parking_spaces', interaction_index='required_car_parking_spaces', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='arrival_date_month', interaction_index='arrival_date_month', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='total_of_special_requests', interaction_index='total_of_special_requests', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='customer_type_Transient', interaction_index='customer_type_Transient', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='previous_cancellations', interaction_index='previous_cancellations', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='stays_in_weekend_nights', interaction_index='stays_in_weekend_nights', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='reservation_status_day_of_week_Sunday', interaction_index='reservation_status_day_of_week_Sunday', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='arrival_date_day', interaction_index='arrival_date_day', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)

# %%
shap.dependence_plot(ind='customer_type_Transient-Party', interaction_index='customer_type_Transient-Party', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
# Out:
# Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.

# %%
shap.dependence_plot(ind='adr', interaction_index='adr', 
                     shap_values = shap_values[1], 
                     features = X_test, 
                     display_features = X_test)
